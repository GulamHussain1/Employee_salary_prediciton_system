# %%
import matplotlib.pyplot as plt

# Example dictionary of model performance (update with your actual scores)
results = {
    "Linear Regression": 0.72,
    "Random Forest": 0.86,
    "Gradient Boosting": 0.91,
    "XGBoost": 0.90
}

# Bar plot of model performance
plt.figure(figsize=(8, 5))
plt.bar(results.keys(), results.values(), color='skyblue')
plt.ylabel("R² Score")
plt.title("Model Comparison")
plt.ylim(0, 1.0)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
for model_name, score in results.items():
    print(f"✅ {model_name:<20}: R² Score = {score:.4f}")
# Out:
# ✅ Linear Regression   : R² Score = 0.7200
# ✅ Random Forest       : R² Score = 0.8600
# ✅ Gradient Boosting   : R² Score = 0.9100
# ✅ XGBoost             : R² Score = 0.9000
